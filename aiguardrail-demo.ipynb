# %% [markdown]
# # AIGuardrail
# A library that evaluates AI-generated content against a catalog of guardrails, providing a final score. It includes checks for hallucination detection, output moderation, and response quality.
#
# https://pypi.org/project/aiguardrail/
#
# 🚀 Features
# - **Output Moderation**: Detect toxic, offensive, or inappropriate language.
# - **Factual Consistency & Hallucination Detection**: Prevent AI-generated inaccuracies or hallucinated information.
# - **PII Redaction**: Identify and flag personally identifiable information (PII).
# - **Prompt Injection Protection**: Detect potential prompt injection attacks.
# - **Token Management**: Optimize content length based on token limits.
# - **Response Quality Checks**: Evaluate readability, verbosity, and bias in AI outputs.

# %%
pip install aiguardrail
# Out:
# Collecting aiguardrail
#   Downloading aiguardrail-0.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from aiguardrail) (2.2.3)
# Collecting tiktoken (from aiguardrail)
#   Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_aarch64.whl.metadata (6.7 kB)
# Collecting detoxify (from aiguardrail)
#   Downloading detoxify-0.5.2-py3-none-any.whl.metadata (13 kB)
# Collecting textstat (from aiguardrail)
#   Downloading textstat-0.7.13-py3-none-any.whl.metadata (15 kB)
# Collecting transformers (from detoxify->aiguardrail)
#   Downloading transformers-5.2.0-py3-none-any.whl.metadata (32 kB)
# Collecting torch>=1.7.0 (from detoxify->aiguardrail)
#   Downloading torch-2.10.0-cp312-cp312-manylinux_2_28_aarch64.whl.metadata (31 kB)
# Collecting sentencepiece>=0.1.94 (from detoxify->aiguardrail)
#   Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.26.0 in /databricks/python3/lib/python3.12/site-packages (from pandas->aiguardrail) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.12/site-packages (from pandas->aiguardrail) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->aiguardrail) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas->aiguardrail) (2024.1)
# Collecting pyphen (from textstat->aiguardrail)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting nltk (from textstat->aiguardrail)
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from textstat->aiguardrail) (74.0.0)
# Collecting regex>=2022.1.18 (from tiktoken->aiguardrail)
#   Downloading regex-2026.2.28-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /databricks/python3/lib/python3.12/site-packages (from tiktoken->aiguardrail) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->aiguardrail) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->aiguardrail) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->aiguardrail) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->aiguardrail) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->aiguardrail) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->detoxify->aiguardrail) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.7.0->detoxify->aiguardrail) (4.12.2)
# Collecting sympy>=1.13.3 (from torch>=1.7.0->detoxify->aiguardrail)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.7.0->detoxify->aiguardrail)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.7.0->detoxify->aiguardrail) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.7.0->detoxify->aiguardrail) (2023.5.0)
# Requirement already satisfied: click in /databricks/python3/lib/python3.12/site-packages (from nltk->textstat->aiguardrail) (8.1.7)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.12/site-packages (from nltk->textstat->aiguardrail) (1.4.2)
# Collecting tqdm (from nltk->textstat->aiguardrail)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers->detoxify->aiguardrail)
#   Downloading huggingface_hub-1.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from transformers->detoxify->aiguardrail) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /databricks/python3/lib/python3.12/site-packages (from transformers->detoxify->aiguardrail) (6.0.2)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->detoxify->aiguardrail)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (7.3 kB)
# Collecting typer-slim (from transformers->detoxify->aiguardrail)
#   Downloading typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting safetensors>=0.4.3 (from transformers->detoxify->aiguardrail)
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (4.1 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail)
#   Downloading hf_xet-1.3.2-cp37-abi3-manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (0.27.0)
# Collecting typer (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.7.0->detoxify->aiguardrail)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch>=1.7.0->detoxify->aiguardrail) (3.0.2)
# Requirement already satisfied: anyio in /databricks/python3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (4.6.2)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (1.0.2)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (0.14.0)
# Collecting click (from nltk->textstat->aiguardrail)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=12.3.0 in /databricks/python3/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (13.9.4)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify->aiguardrail) (0.1.0)
# Downloading aiguardrail-0.1.0-py3-none-any.whl (7.0 kB)
# Downloading detoxify-0.5.2-py3-none-any.whl (12 kB)
# Downloading textstat-0.7.13-py3-none-any.whl (177 kB)
# Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_aarch64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.7 MB/s eta 0:00:00
# Downloading regex-2026.2.28-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.8/796.8 kB 13.6 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.1 MB/s eta 0:00:00
# Downloading torch-2.10.0-cp312-cp312-manylinux_2_28_aarch64.whl (146.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 MB 94.7 MB/s eta 0:00:00
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.0 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.1 MB/s eta 0:00:00
# Downloading transformers-5.2.0-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 85.6 MB/s eta 0:00:00
# Downloading huggingface_hub-1.5.0-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 26.2 MB/s eta 0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 46.9 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (491 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 60.9 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 73.5 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Downloading hf_xet-1.3.2-cp37-abi3-manylinux_2_28_aarch64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 112.1 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.8 MB/s eta 0:00:00
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, tqdm, sympy, shellingham, sentencepiece, safetensors, regex, pyphen, networkx, hf-xet, click, annotated-doc, torch, tiktoken, nltk, typer, textstat, typer-slim, huggingface-hub, tokenizers, transformers, detoxify, aiguardrail
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Not uninstalling click at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-edc0788e-2d69-4659-a42f-bd7aee42f5ab
#     Can't uninstall 'click'. No files were found to uninstall.
# Successfully installed aiguardrail-0.1.0 annotated-doc-0.0.4 click-8.3.1 detoxify-0.5.2 hf-xet-1.3.2 huggingface-hub-1.5.0 mpmath-1.3.0 networkx-3.6.1 nltk-3.9.3 pyphen-0.17.2 regex-2026.2.28 safetensors-0.7.0 sentencepiece-0.2.1 shellingham-1.5.4 sympy-1.14.0 textstat-0.7.13 tiktoken-0.12.0 tokenizers-0.22.2 torch-2.10.0 tqdm-4.67.3 transformers-5.2.0 typer-0.24.1 typer-slim-0.24.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %% [markdown]
# ### Available guardrails

# %%
from aiguardrail.guardrails import list_available_guardrails

guardrails = list_available_guardrails()
for gr in guardrails:
    print(f"{gr['id']} - {gr['name']} [{gr['area']}]")
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-edc0788e-2d69-4659-a42f-bd7aee42f5ab/lib/python3.12/site-packages/torch/_vmap_internals.py:9: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   from torch.utils._pytree import _broadcast_to_and_flatten, tree_flatten, tree_unflatten
# GR-S-001 - Output Moderation [Security]
# GR-Q-001 - Hallucination Detection [Quality]
# GR-S-005 - PII Redaction [Security]
# GR-S-006 - Prompt Injection Detection [Security]
# GR-Q-005 - Factual Consistency [Quality]
# GR-C-002 - Token Budget [Cost]
# GR-C-009 - Response Length [Cost]
# GR-S-002 - Bias Detection [Quality]
# GR-S-004 - Data Leakage [Security]
# GR-C-001 - Prompt Length [Cost]
# GR-Q-004 - Controllability [Quality]
# GR-Q-006 - Readability Check [Quality]

# %% [markdown]
# ### Evaluate text quickly against all available guardrails

# %%
from aiguardrail.guardrails import evaluate_guardrails

text = "According to the source, this event took place in March."

results_df, final_score = evaluate_guardrails(text)

print(results_df)
print(f"Overall Guardrail Score: {final_score}")
# Out:
# Downloading: "https://github.com/unitaryai/detoxify/releases/download/v0.1-alpha/toxic_original-c1212f89.ckpt" to /home/spark-edc0788e-2d69-4659-a42f-bd/.cache/torch/hub/checkpoints/toxic_original-c1212f89.ckpt
# 100%|██████████| 418M/418M [00:03<00:00, 146MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: None
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
#    Guardrail ID  ...                                Comment
# 0      GR-S-001  ...              No toxic content detected
# 1      GR-Q-001  ...                     Grounded in source
# 2      GR-S-005  ...                        No PII detected
# 3      GR-S-006  ...       No suspicious injection patterns
# 4      GR-Q-005  ...          Answer consistent with source
# 5      GR-C-002  ...             Token usage acceptable: 12
# 6      GR-C-009  ...                  Length and clarity OK
# 7      GR-S-002  ...             No obvious biased phrasing
# 8      GR-S-004  ...                    No leakage detected
# 9      GR-C-001  ...             Prompt length OK: 10 words
# 10     GR-Q-004  ...  Missing explicit controllability cues
# 11     GR-Q-006  ...      Readable: Score 86.70500000000001
#
# [12 rows x 6 columns]
# Overall Guardrail Score: 97

# %% [markdown]
# ### Evaluate specific guardrails only

# %%
specific_guardrails = ["GR-S-001", "GR-Q-005", "GR-C-002"]

results_df, final_score = evaluate_guardrails(text, selected_guardrail_ids=specific_guardrails)

print(results_df)
print(f"Overall Guardrail Score: {final_score}")
# Out:
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: None
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
#   Guardrail ID                 Name  ... StatusRaw                        Comment
# 0     GR-S-001    Output Moderation  ...      pass      No toxic content detected
# 1     GR-Q-005  Factual Consistency  ...      pass  Answer consistent with source
# 2     GR-C-002         Token Budget  ...      pass     Token usage acceptable: 12
#
# [3 rows x 6 columns]
# Overall Guardrail Score: 100
